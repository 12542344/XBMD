# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from PIL import Image
import torch
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import datasets, models, transforms
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import lightning as L
from lightning.pytorch.callbacks.early_stopping import EarlyStopping
# Out:
# /tmp/ipykernel_203686/3725667653.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
def img_display(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    npimg = np.transpose(npimg, (1, 2, 0))
    return npimg

class XBMD_Dataset(Dataset):
    def __init__(self, img_data, img_path,transform=None):
        self.img_path = img_path
        self.transform = transform
        self.img_data = img_data

    def __len__(self):
        return len(self.img_data)
    
    def __getitem__(self, index):
        image_address = os.path.join(self.img_path, self.img_data.loc[index, 'image'])
        image = Image.open(image_address).convert("RGB")
        image = image.resize((384,384))
        value = torch.tensor(self.img_data.loc[index, 'bmd_scaled'])
        if self.transform is not None:
            image = self.transform(image)
        return image_address, image.float(), value.float()
    
class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = models.regnet_y_16gf(weights = "IMAGENET1K_SWAG_E2E_V1")
        self.regressor = nn.Sequential(nn.Linear(1000, 500)
                                      ,nn.Linear(500, 1))

    def forward(self, x):
        x=self.backbone(x)
        x=self.regressor(x)
        return x
    
def descale(value, MEAN, SD):
    return value * SD + MEAN

# %%
home_path = "/projects/ghnguyen_proj/project/git/ebmd/"
dataset_address = home_path + "data/vertebra_maskI/"
df = pd.read_csv(home_path + "instruction/lsbmd_phase1_instruction.csv")
df["image"] = dataset_address + df["FNAME"]
df["bmd_scaled"] = (df["BMD"] - df["mBMD"]) / df["sdBMD"] 
df["vertebra"] = df["LNAME"]
df["purpose"] = df["PURPOSE"]
df['exist'] = df['image'].map(os.path.exists)
df['bmd_category'] = pd.cut(df['bmd_scaled'], 50, labels=range(50)).astype("int")
df[['bmd_scaled']].hist(figsize = (10, 4))
print('images found of', df.shape[0], 'total')
raw_train_df = df[df['purpose'].isin(["TRAIN"])]
valid_df =  df[df['purpose'].isin(["VALID"])]
print('Train amount: ', raw_train_df.shape[0], 'Validation amount: ', valid_df.shape[0])
train_df = raw_train_df.groupby(['bmd_category']).apply(lambda x: x.sample(max(raw_train_df["bmd_category"].value_counts()), replace = True)).reset_index(drop = True)
train_df[['bmd_scaled']].hist(figsize = (10, 4), bins=50)
print('New Data Size:', train_df.shape[0], 'Old Size:', raw_train_df.shape[0])
# Out:
# images found of 13498 total
# Train amount:  7554 Validation amount:  1976
# New Data Size: 15350 Old Size: 7554

# %%
BATCH_SIZE = 32

train_indices = list(train_df.index)
train_sampler = SubsetRandomSampler(train_indices)
train_transform = transforms.Compose(
    [transforms.ToTensor()
    ,transforms.RandomVerticalFlip()
    ,transforms.RandomHorizontalFlip()
    ,transforms.RandomAffine(degrees=(0, 5), translate=(0, 0.1), scale=(0.8, 1.2))
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
train_dataset = XBMD_Dataset(train_df, dataset_address, train_transform)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=train_sampler)

valid_indices = list(valid_df.index)
valid_sampler = SubsetRandomSampler(valid_indices)
valid_transform = transforms.Compose(
    [transforms.ToTensor()                                
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
valid_dataset = XBMD_Dataset(valid_df, dataset_address, valid_transform)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, sampler=valid_sampler)

# %%
dataiter = iter(train_loader)
_, images, values = next(dataiter)
fig, axis = plt.subplots(5, 5, figsize=(18, 18))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, value = images[i], values[i]
        ax.imshow(img_display(image)@ [0.299, 0.587, 0.113], cmap = "gray")
        ax.set(title = f"{round(value.item(),3)}")

# %%
device = torch.device("cuda:1")
model = Network()
model.to(device)
print("Model initialised")
# Out:
# Model initialised

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
model_path = 'model/lsbmd/RegNetY16F/RegNetY16F_M'

# %%
def descale(value, MEAN, SD):
    return value * SD + MEAN

n_epochs = 30
print_every = 1
description = "e31-60"

try:
    old_file_existed = True
    record_current = pd.read_csv(home_path + model_path + ".csv")
    record_new = []
    train_loss = record_current["train_loss"].to_list()
    val_loss = record_current["val_loss"].to_list()
    valid_loss_min = np.min(val_loss)
    learning_rate = record_current["lr"].values[-1]
    print("Old file existed.")
except:
    old_file_existed = False
    record_current = []
    record_new = []
    train_loss = []
    val_loss = []
    valid_loss_min = np.inf
    learning_rate = 0.001
    print("Old file not existed, create new file...")

print("learning rate: ", learning_rate)

total_step = len(train_loader)

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)
scheduler = ReduceLROnPlateau(optimizer, 'min', patience = 5)

for epoch in range(1, n_epochs+1):
    model.train()
    running_loss = 0.0
    correct = 0
    total=0
    with tqdm(train_loader, unit="batch") as tepoch:
        tepoch.set_description(f'Epoch [{epoch}/{n_epochs}]') #print epoch
        for batch_idx, (_, data_, target_) in enumerate(tepoch):
            data_, target_ = data_.to(device), target_.to(device)# on GPU
            optimizer.zero_grad()
            outputs = model(data_)
            loss = criterion(outputs, target_.unsqueeze(1))
            loss.backward()
            optimizer.step()
            running_loss += loss.item()    
        batch_loss = 0
        total_t=0
        correct_t=0
        with torch.no_grad():
            model.eval()
            for _, data_t, target_t in (valid_loader):
                data_t, target_t = data_t.to(device), target_t.to(device)
                outputs_t = model(data_t)
                loss_t = criterion(outputs_t, target_t.unsqueeze(1))
                batch_loss += loss_t.item()
            val_loss = np.append(val_loss, batch_loss/len(valid_loader))
            network_learned = batch_loss/len(valid_loader) < valid_loss_min
            if network_learned: 
                valid_loss_min = batch_loss/len(valid_loader)
                torch.save(model.state_dict(), home_path + model_path + "_" + description + '.pt')
                print('Detected network improvement, saving current model')
        scheduler.step(np.mean(val_loss))
        record_new.append([running_loss/total_step, batch_loss/len(valid_loader), optimizer.param_groups[0]['lr'], description])
    print('Train loss: {:.4f}, Valid loss: {:.4f}, Learn rate: {:.4f}\n' 
       .format(running_loss/total_step, batch_loss/len(valid_loader), optimizer.param_groups[0]['lr']))

model_test = Network()
model_test.load_state_dict(torch.load(home_path + model_path + "_" + description + '.pt'))
model_test.to("cpu")

test_df =  df[df['purpose'].isin(["TEST"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true = []
Y_pred = []
with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        output_ = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output_.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))
if old_file_existed == True:
    record_new = pd.DataFrame(record_new, columns = ["train_loss","val_loss","lr","note"])
    record_new["epoch"] = range((np.max(record_current["epoch"])+1),(np.max(record_current["epoch"])+1+n_epochs),1)
    pd.concat([record_current, record_new], axis=0).reset_index(drop=True).to_csv(home_path + model_path + '.csv', index = False)   
    results_current = pd.read_csv(home_path + model_path + "_TESTRESULTS.csv")
    results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
    pd.concat([results_current, results_new], axis=0).reset_index(drop=True).to_csv(home_path + model_path + '_TESTRESULTS.csv', index = False)
else:
    record_new = pd.DataFrame(record_new, columns = ["train_loss","val_loss","lr","note"])
    record_new["epoch"] = range(1,n_epochs+1,1)
    record_new.reset_index(drop=True).to_csv(home_path + model_path + '.csv', index =False)   
    results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
    results_new.reset_index(drop=True).to_csv(home_path + model_path + '_TESTRESULTS.csv', index =False)
print("Round completed")
# Out:
# Old file existed.
# learning rate:  0.001
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1682, Valid loss: 0.8134, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1653, Valid loss: 0.7911, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1517, Valid loss: 0.8668, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1458, Valid loss: 0.8489, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1449, Valid loss: 0.8060, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1404, Valid loss: 0.7835, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1372, Valid loss: 0.7946, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1274, Valid loss: 0.8246, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1256, Valid loss: 0.7812, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1190, Valid loss: 0.8212, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1147, Valid loss: 0.7791, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1112, Valid loss: 0.8025, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1094, Valid loss: 0.8316, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1075, Valid loss: 0.7756, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1034, Valid loss: 0.7834, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1000, Valid loss: 0.7772, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1036, Valid loss: 0.7772, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0938, Valid loss: 0.7766, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0918, Valid loss: 0.9114, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0894, Valid loss: 0.7669, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0925, Valid loss: 0.7898, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.0868, Valid loss: 0.7563, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0869, Valid loss: 0.7605, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.0808, Valid loss: 0.7553, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0826, Valid loss: 0.8644, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.0795, Valid loss: 0.7399, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0776, Valid loss: 0.7492, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0756, Valid loss: 0.7463, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0763, Valid loss: 0.7509, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0726, Valid loss: 0.7761, Learn rate: 0.0010
#
# Round completed

# %%
for epoch in range(1, n_epochs+1):
    model.train()
    running_loss = 0.0
    correct = 0
    total=0
    with tqdm(train_loader, unit="batch") as tepoch:
        tepoch.set_description(f'Epoch [{epoch}/{n_epochs}]') #print epoch
        for batch_idx, (_, data_, target_) in enumerate(tepoch):
            data_, target_ = data_.to(device), target_.to(device)# on GPU
            optimizer.zero_grad()
            outputs = model(data_)
            loss = criterion(outputs, target_.unsqueeze(1))
            loss.backward()
            optimizer.step()
            running_loss += loss.item()    
        batch_loss = 0
        total_t=0
        correct_t=0
        with torch.no_grad():
            model.eval()
            for _, data_t, target_t in (valid_loader):
                data_t, target_t = data_t.to(device), target_t.to(device)
                outputs_t = model(data_t)
                loss_t = criterion(outputs_t, target_t.unsqueeze(1))
                batch_loss += loss_t.item()
            val_loss = np.append(val_loss, batch_loss/len(valid_loader))
            network_learned = batch_loss/len(valid_loader) < valid_loss_min
            if network_learned: 
                valid_loss_min = batch_loss/len(valid_loader)
                torch.save(model.state_dict(), home_path + model_path + "_" + description + '.pt')
                print('Detected network improvement, saving current model')
        scheduler.step(np.mean(val_loss))
        record_new.append([running_loss/total_step, batch_loss/len(valid_loader), optimizer.param_groups[0]['lr'], description])
    print('Train loss: {:.4f}, Valid loss: {:.4f}, Learn rate: {:.4f}\n' 
       .format(running_loss/total_step, batch_loss/len(valid_loader), optimizer.param_groups[0]['lr']))

model_test = Network()
model_test.load_state_dict(torch.load(home_path + model_path + "_" + description + '.pt'))
model_test.to("cpu")

test_df =  df[df['purpose'].isin(["TEST"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true = []
Y_pred = []
with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        output_ = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output_.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))
if old_file_existed == True:
    record_new = pd.DataFrame(record_new, columns = ["train_loss","val_loss","lr","note"])
    record_new["epoch"] = range((np.max(record_current["epoch"])+1),(np.max(record_current["epoch"])+1+n_epochs),1)
    pd.concat([record_current, record_new], axis=0).reset_index(drop=True).to_csv(home_path + model_path + '.csv', index = False)   
    results_current = pd.read_csv(home_path + model_path + "_TESTRESULTS.csv")
    results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
    pd.concat([results_current, results_new], axis=0).reset_index(drop=True).to_csv(home_path + model_path + '_TESTRESULTS.csv', index = False)
else:
    record_new = pd.DataFrame(record_new, columns = ["train_loss","val_loss","lr","note"])
    record_new["epoch"] = range(1,n_epochs+1,1)
    record_new.reset_index(drop=True).to_csv(home_path + model_path + '.csv', index =False)   
    results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
    results_new.reset_index(drop=True).to_csv(home_path + model_path + '_TESTRESULTS.csv', index =False)
print("Round completed")
# Out:
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 1.2619, Valid loss: 0.8743, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 1.0501, Valid loss: 1.1298, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.9065, Valid loss: 0.8578, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.8127, Valid loss: 0.8633, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.7476, Valid loss: 0.8304, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.6937, Valid loss: 0.9362, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.6394, Valid loss: 0.9234, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.5978, Valid loss: 0.9426, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.5540, Valid loss: 0.8686, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.5170, Valid loss: 0.8992, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.4814, Valid loss: 0.8802, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.4569, Valid loss: 0.8148, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.4278, Valid loss: 0.8774, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.4003, Valid loss: 0.8342, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.3760, Valid loss: 0.8055, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.3609, Valid loss: 0.8880, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.3402, Valid loss: 0.8795, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.3155, Valid loss: 0.8819, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.2984, Valid loss: 0.8050, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.2805, Valid loss: 0.8281, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.2697, Valid loss: 0.8195, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.2569, Valid loss: 0.8577, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.2370, Valid loss: 0.8448, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.2333, Valid loss: 0.8102, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.2204, Valid loss: 0.8078, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.2130, Valid loss: 0.7642, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1974, Valid loss: 0.8349, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1917, Valid loss: 0.8144, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1767, Valid loss: 0.7670, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1772, Valid loss: 0.8367, Learn rate: 0.0010
#
# Round completed

# %% [markdown]
# # Validation

# %%
device = torch.device("cuda:1")
model_path = 'model/lsbmd/RegNetY16F/RegNetY16F'
model_test = Network()
model_test.load_state_dict(torch.load("../model/lsbmd/RegNetY16F/RegNetY16F_e31-60.pt"))
model_test.to("cuda:1")
description = "e31-60"

test_df =  df[df['purpose'].isin(["VALID"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true = []
Y_pred = []

with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        print(image_address)
        image, value = image.to(device), value.to(device)
        output = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))  

results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
results_new.reset_index(drop=True).to_csv(home_path + model_path + '_VALIDRESULTS.csv', index =False)
print("Round completed")
# Out:
# Network(
#   (backbone): RegNet(
#     (stem): SimpleStemIN(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (trunk_output): Sequential(
#       (block1): AnyStage(
#         (block1-0): ResBottleneckBlock(
#           (proj): Conv2dNormActivation(
#             (0): Conv2d(32, 224, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(32, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(224, 224, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=2, bias=False)
#               (1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(224, 8, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(8, 224, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(224, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block1-1): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(224, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(224, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2, bias=False)
#               (1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(224, 56, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(56, 224, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(224, 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#       )
#       (block2): AnyStage(
#         (block2-0): ResBottleneckBlock(
#           (proj): Conv2dNormActivation(
#             (0): Conv2d(224, 448, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(224, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(448, 448, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=4, bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(448, 56, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(56, 448, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block2-1): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(448, 112, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(112, 448, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block2-2): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(448, 112, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(112, 448, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block2-3): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(448, 448, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4, bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(448, 112, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(112, 448, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(448, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#       )
#       (block3): AnyStage(
#         (block3-0): ResBottleneckBlock(
#           (proj): Conv2dNormActivation(
#             (0): Conv2d(448, 1232, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(448, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=11, bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1232, 112, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(112, 1232, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block3-1): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1232, 308, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(308, 1232, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block3-2): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1232, 308, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(308, 1232, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block3-3): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1232, 308, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(308, 1232, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block3-4): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1232, 308, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(308, 1232, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block3-5): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1232, 308, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(308, 1232, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block3-6): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1232, 308, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(308, 1232, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block3-7): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1232, 308, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(308, 1232, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block3-8): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1232, 308, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(308, 1232, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block3-9): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1232, 308, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(308, 1232, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#         (block3-10): ResBottleneckBlock(
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=11, bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1232, 308, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(308, 1232, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(1232, 1232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#       )
#       (block4): AnyStage(
#         (block4-0): ResBottleneckBlock(
#           (proj): Conv2dNormActivation(
#             (0): Conv2d(1232, 3024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(3024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (f): BottleneckTransform(
#             (a): Conv2dNormActivation(
#               (0): Conv2d(1232, 3024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(3024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (b): Conv2dNormActivation(
#               (0): Conv2d(3024, 3024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=27, bias=False)
#               (1): BatchNorm2d(3024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU(inplace=True)
#             )
#             (se): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(3024, 308, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(308, 3024, kernel_size=(1, 1), stride=(1, 1))
#               (activation): ReLU()
#               (scale_activation): Sigmoid()
#             )
#             (c): Conv2dNormActivation(
#               (0): Conv2d(3024, 3024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(3024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (activation): ReLU(inplace=True)
#         )
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=3024, out_features=1000, bias=True)
#   )
#   (regressor): Sequential(
#     (0): Linear(in_features=1000, out_features=500, bias=True)
#     (1): Linear(in_features=500, out_features=1, bias=True)
#   )
# )

# %%
home_path = "/projects/ghnguyen_proj/project/git/ebmd/"
dataset_address = home_path + "data/hip/total/"
df = pd.read_csv(home_path + "instruction/fnbmd_phase1_instruction.csv")
df["image"] = dataset_address + df["FNAME"]
df["bmd_scaled"] = (df["BMD"] - df["mBMD"]) / df["sdBMD"]
df["purpose"] = df["PURPOSE"]
df['exist'] = df['image'].map(os.path.exists)
df['bmd_category'] = pd.cut(df['bmd_scaled'], 50, labels=range(50)).astype("int")
df[['bmd_scaled']].hist(figsize = (10, 4))
valid_df =  df[df['purpose'].isin(["VALID"])]

device = torch.device("cuda:1")
model_path = 'model/fnbmd/RegNetY16F/RegNetY16F'
model_test = Network()
model_test.load_state_dict(torch.load("../model/fnbmd/RegNet16F/RegNetY16F_e01-30.pt"))
model_test.to(device)
description = "Ensemble"

test_df =  df[df['purpose'].isin(["VALID"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true = []
Y_pred = []

with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        print(image_address)
        image, value = image.to(device), value.to(device)
        output = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))  

results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
results_new.reset_index(drop=True).to_csv(home_path + model_path + '_VALIDRESULTS.csv', index =False)
print("Round completed")
# Out:
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2396.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2959.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3984.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4116.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3408.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2492.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3403.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/832.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/737.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1082.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1297.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4152.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1825.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1207.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1208.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3701.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2561.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3271.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2558.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4190.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3745.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3511.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2331.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2911.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1953.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/864.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2562.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2559.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1525.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1129.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3879.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3706.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4137.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1276.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2674.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1648.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3549.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2807.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2878.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2327.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1493.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2758.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4154.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2586.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4177.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/580.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3207.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2049.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/600.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3642.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2512.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1497.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2870.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/836.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/575.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2752.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4068.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1059.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2251.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/699.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3683.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2847.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1760.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3512.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2824.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2661.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1330.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/467.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1707.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/101.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2967.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3395.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2189.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1859.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3808.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2104.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3388.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2927.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4168.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1828.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/738.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2990.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3047.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2027.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1084.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2966.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3542.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1294.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3367.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/322.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2509.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2658.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/161.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2636.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2121.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2889.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1226.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1250.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2616.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/702.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2834.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3740.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1306.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1737.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/773.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2531.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1055.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3506.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3224.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/79.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4203.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/64.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1144.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3023.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3228.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1437.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3420.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3345.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2276.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3988.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2943.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3835.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3530.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2236.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/555.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/437.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2792.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/363.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1241.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3347.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3878.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1288.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3723.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/208.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1452.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3909.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2408.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2525.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4076.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3700.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/945.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2058.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2617.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3028.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1994.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/954.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/430.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/782.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/596.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2537.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/706.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2750.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2466.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2018.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2404.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3452.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1122.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3529.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2315.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4096.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3657.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/913.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/631.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/108.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3914.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/618.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4077.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1747.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3233.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4134.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3343.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2067.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/390.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3726.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3527.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2995.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/757.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/906.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3876.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/933.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3151.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1424.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/471.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/705.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2672.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1145.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2547.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3896.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2423.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1445.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/28.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2169.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3997.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/639.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3551.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2383.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3278.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2934.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2682.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3007.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2471.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1897.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1232.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1379.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1977.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3484.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2286.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2515.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3289.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1878.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2950.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/44.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/860.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2263.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3772.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1789.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/15.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1657.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3295.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/709.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3377.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3454.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3823.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2458.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3671.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2560.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2112.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4014.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/792.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3382.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/646.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3817.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/233.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/349.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4104.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1359.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3778.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4169.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1003.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/442.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1844.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2314.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1303.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3868.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/343.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1435.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2011.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/99.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/522.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2372.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1939.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1118.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2830.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2801.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1564.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/823.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1002.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3369.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3875.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/235.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3947.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2556.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1344.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/719.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/243.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1110.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/480.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3201.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1871.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3489.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1481.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1578.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3146.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1574.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1246.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3919.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3931.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2231.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2501.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1124.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3689.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/295.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/770.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/491.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1394.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/242.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/556.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/429.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1092.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1441.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/483.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4161.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/871.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/755.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3020.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1240.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2983.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2168.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/406.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1060.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2599.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1091.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1675.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2106.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1064.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3747.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1981.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/886.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1933.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1228.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/232.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1561.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/928.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1517.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3737.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2511.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/873.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1193.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/12.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1054.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/707.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2480.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3946.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1377.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1364.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/971.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3476.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/291.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/780.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2090.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/884.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2669.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1920.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1187.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3680.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2592.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2788.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2604.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3422.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3890.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/327.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/730.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/671.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3460.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2131.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/804.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4023.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1428.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3284.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1258.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3795.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/151.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3310.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2313.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3943.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2223.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/867.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3972.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3911.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2175.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2201.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1221.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2880.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1066.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/17.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1989.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/318.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1904.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/249.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3949.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3555.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/76.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3288.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1519.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1387.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4179.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3038.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3315.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3299.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4140.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3942.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1164.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/499.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4090.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3440.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3930.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1159.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2234.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3129.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/454.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2268.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/203.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2309.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2893.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4087.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2554.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1421.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/370.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/911.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1921.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2815.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/595.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1958.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/216.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2172.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3199.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2523.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3524.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2386.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/583.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1295.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2219.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/450.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/136.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2770.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1969.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3145.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1690.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3746.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1788.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3882.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2745.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3270.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1742.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2068.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3276.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1701.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3959.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/837.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3702.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3095.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1037.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2220.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/568.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2761.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3277.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/806.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/781.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1484.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3198.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3478.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2208.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3784.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2265.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1425.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3968.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2517.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/427.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1530.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3487.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3751.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3130.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2726.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3111.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3061.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3948.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/209.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/628.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2467.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3986.png
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 42
#      39         Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))
#      41 results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
# ---> 42 results_new.reset_index(drop=True).to_csv(home_path + model_path + '_VALIDRESULTS.csv', index =False)
#      43 print("Round completed")
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '/projects/ghnguyen_proj/project/git/ebmd/model/fnbmd/RegNetY16F'

# %%
home_path = "/projects/ghnguyen_proj/project/git/ebmd/"
dataset_address = home_path + "data/vertebra/"
df = pd.read_csv(home_path + "instruction/lsbmd_phase1_instruction.csv")
df["image"] = dataset_address + df["FNAME"]
df["bmd_scaled"] = (df["BMD"] - df["mBMD"]) / df["sdBMD"]
df["purpose"] = df["PURPOSE"]
df['exist'] = df['image'].map(os.path.exists)
df['bmd_category'] = pd.cut(df['bmd_scaled'], 50, labels=range(50)).astype("int")
df[['bmd_scaled']].hist(figsize = (10, 4))

device = torch.device("cuda:1")
model_path = 'model/lsbmd/RegNetY16F/RegNetY16F_ENSEMBLE'
model_test = Network()
model_test.load_state_dict(torch.load("../model/lsbmd/RegNetY16F/RegNetY16F_e31-60.pt"))
model_test.to(device)

test_df =  df[df['purpose'].isin(["TEST"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true, Y_pred = [], []
with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        image, value = image.to(device), value.to(device)
        output_ = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output_.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))

results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred})
results_new["X"] = results_new["X"].apply(os.path.basename)
results_new.reset_index(drop=True).to_csv(home_path + model_path + '_TEST.csv', index =False)

test_df =  df[df['purpose'].isin(["VALID"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true, Y_pred = [], []
with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        image, value = image.to(device), value.to(device)
        output_ = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output_.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))

results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred})
results_new["X"] = results_new["X"].apply(os.path.basename)
results_new.reset_index(drop=True).to_csv(home_path + model_path + '_TRAIN.csv', index =False)
print("Round completed")
# Out:
# Round completed
