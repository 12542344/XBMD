# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from PIL import Image
import torch
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import datasets, models, transforms
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import lightning as L
from lightning.pytorch.callbacks.early_stopping import EarlyStopping

# %%
def img_display(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    npimg = np.transpose(npimg, (1, 2, 0))
    return npimg

class XBMD_Dataset(Dataset):
    def __init__(self, img_data, img_path,transform=None):
        self.img_path = img_path
        self.transform = transform
        self.img_data = img_data

    def __len__(self):
        return len(self.img_data)
    
    def __getitem__(self, index):
        image_address = os.path.join(self.img_path, self.img_data.loc[index, 'image'])
        image = Image.open(image_address).convert("RGB")
        image = image.resize((384,384))
        value = torch.tensor(self.img_data.loc[index, 'bmd_scaled'])
        if self.transform is not None:
            image = self.transform(image)
        return image_address, image.float(), value.float()
    
class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = models.resnet34(weights = "IMAGENET1K_V1")
        self.regressor = nn.Sequential(nn.Linear(1000, 500)
                                      ,nn.Linear(500, 1))

    def forward(self, x):
        x=self.backbone(x)
        x=self.regressor(x)
        return x

# %%
home_path = "/projects/ghnguyen_proj/project/git/ebmd/"
dataset_address = home_path + "data/vertebra/"
df = pd.read_csv(home_path + "instruction/lsbmd_phase1_instruction.csv")
df["image"] = dataset_address + df["FNAME"]
df["bmd_scaled"] = (df["BMD"] - df["mBMD"]) / df["sdBMD"] 
df["purpose"] = df["PURPOSE"]
df['exist'] = df['image'].map(os.path.exists)
df['bmd_category'] = pd.cut(df['bmd_scaled'], 50, labels=range(50)).astype("int")
df[['bmd_scaled']].hist(figsize = (10, 4))
print('images found of', df.shape[0], 'total')
raw_train_df = df[df['purpose'].isin(["TRAIN"])]
valid_df =  df[df['purpose'].isin(["VALID"])]
print('Train amount: ', raw_train_df.shape[0], 'Validation amount: ', valid_df.shape[0])
train_df = raw_train_df.groupby(['bmd_category']).apply(lambda x: x.sample(max(raw_train_df["bmd_category"].value_counts()), replace = True)).reset_index(drop = True)
train_df[['bmd_scaled']].hist(figsize = (10, 4), bins=50)
print('New Data Size:', train_df.shape[0], 'Old Size:', raw_train_df.shape[0])
# Out:
# images found of 13498 total
# Train amount:  7554 Validation amount:  1976
# New Data Size: 15350 Old Size: 7554

# %%
BATCH_SIZE = 32

train_indices = list(train_df.index)
train_sampler = SubsetRandomSampler(train_indices)
train_transform = transforms.Compose(
    [transforms.ToTensor()
    ,transforms.RandomVerticalFlip()
    ,transforms.RandomAffine(degrees=(0, 5), translate=(0, 0.1), scale=(0.8, 1.2))
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
train_dataset = XBMD_Dataset(train_df, dataset_address, train_transform)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=train_sampler)

valid_indices = list(valid_df.index)
valid_sampler = SubsetRandomSampler(valid_indices)
valid_transform = transforms.Compose(
    [transforms.ToTensor()                                
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
valid_dataset = XBMD_Dataset(valid_df, dataset_address, valid_transform)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, sampler=valid_sampler)

# %%
dataiter = iter(train_loader)
_, images, values = next(dataiter)
fig, axis = plt.subplots(5, 5, figsize=(18, 18))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, value = images[i], values[i]
        ax.imshow(img_display(image)@ [0.299, 0.587, 0.113], cmap = "gray")
        ax.set(title = f"{round(value.item(),3)}")

# %%
device = torch.device("cuda:1")
model = Network()
model.to(device)
print("Model initialised")
# Out:
# Model initialised

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
model_path = 'model/lsbmd/ResNet34/ResNet34'

# %%
def descale(value, MEAN, SD):
    return value * SD + MEAN

n_epochs = 30
print_every = 1
description = "e61-90"

try:
    old_file_existed = True
    record_current = pd.read_csv(home_path + model_path + ".csv")
    record_new = []
    train_loss = record_current["train_loss"].to_list()
    val_loss = record_current["val_loss"].to_list()
    valid_loss_min = np.min(val_loss)
    learning_rate = record_current["lr"].values[-1]
    print("Old file existed.")
except:
    old_file_existed = False
    record_current = []
    record_new = []
    train_loss = []
    val_loss = []
    valid_loss_min = np.inf
    learning_rate = 0.001
    print("Old file not existed, create new file...")

print("learning rate: ", learning_rate)
    
total_step = len(train_loader)
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)
scheduler = ReduceLROnPlateau(optimizer, 'min', patience = 5)

for epoch in range(1, n_epochs+1):
    model.train()
    running_loss = 0.0
    correct = 0
    total=0
    with tqdm(train_loader, unit="batch") as tepoch:
        tepoch.set_description(f'Epoch [{epoch}/{n_epochs}]') #print epoch
        for batch_idx, (_, data_, target_) in enumerate(tepoch):
            data_, target_ = data_.to(device), target_.to(device)# on GPU
            optimizer.zero_grad()
            outputs = model(data_)
            loss = criterion(outputs, target_.unsqueeze(1))
            loss.backward()
            optimizer.step()
            running_loss += loss.item()    
        batch_loss = 0
        total_t=0
        correct_t=0
        with torch.no_grad():
            model.eval()
            for _, data_t, target_t in (valid_loader):
                data_t, target_t = data_t.to(device), target_t.to(device)
                outputs_t = model(data_t)
                loss_t = criterion(outputs_t, target_t.unsqueeze(1))
                batch_loss += loss_t.item()
            val_loss = np.append(val_loss, batch_loss/len(valid_loader))
            network_learned = batch_loss/len(valid_loader) < valid_loss_min
            if network_learned: 
                valid_loss_min = batch_loss/len(valid_loader)
                torch.save(model.state_dict(), home_path + model_path + "_" + description + '.pt')
                print('Detected network improvement, saving current model')
        scheduler.step(np.mean(val_loss))
        record_new.append([running_loss/total_step, batch_loss/len(valid_loader), optimizer.param_groups[0]['lr'], description])
    print('Train loss: {:.4f}, Valid loss: {:.4f}, Learn rate: {:.4f}\n' 
       .format(running_loss/total_step, batch_loss/len(valid_loader), optimizer.param_groups[0]['lr']))

model_test = Network()
model_test.load_state_dict(torch.load(home_path + model_path + "_" + description + '.pt'))
model_test.to("cpu")

test_df =  df[df['purpose'].isin(["TEST"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true = []
Y_pred = []

with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        output_ = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output_.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))

if old_file_existed == True:
    record_new = pd.DataFrame(record_new, columns = ["train_loss","val_loss","lr","note"])
    record_new["epoch"] = range((np.max(record_current["epoch"])+1),(np.max(record_current["epoch"])+1+n_epochs),1)
    pd.concat([record_current, record_new], axis=0).reset_index(drop=True).to_csv(home_path + model_path + '.csv', index = False)   
    results_current = pd.read_csv(home_path + model_path + "_TESTRESULTS.csv")
    results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
    pd.concat([results_current, results_new], axis=0).reset_index(drop=True).to_csv(home_path + model_path + '_TESTRESULTS.csv', index = False)
else:
    record_new = pd.DataFrame(record_new, columns = ["train_loss","val_loss","lr","note"])
    record_new["epoch"] = range(1,n_epochs+1,1)
    record_new.reset_index(drop=True).to_csv(home_path + model_path + '.csv', index =False)   
    results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
    results_new.reset_index(drop=True).to_csv(home_path + model_path + '_TESTRESULTS.csv', index =False)
print("Round completed")
# Out:
# Old file existed.
# learning rate:  0.001
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.1385, Valid loss: 0.4411, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.1355, Valid loss: 0.4379, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1403, Valid loss: 0.4720, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1373, Valid loss: 0.4422, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.1289, Valid loss: 0.4316, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1317, Valid loss: 0.4461, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1294, Valid loss: 0.4439, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1280, Valid loss: 0.4522, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1262, Valid loss: 0.4371, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1300, Valid loss: 0.4396, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1335, Valid loss: 0.4512, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.1198, Valid loss: 0.4282, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1228, Valid loss: 0.4343, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1301, Valid loss: 0.4290, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1199, Valid loss: 0.4381, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1266, Valid loss: 0.4415, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1206, Valid loss: 0.4379, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1213, Valid loss: 0.4425, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1280, Valid loss: 0.4478, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1201, Valid loss: 0.4471, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1231, Valid loss: 0.4741, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1196, Valid loss: 0.4413, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.1179, Valid loss: 0.4271, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1166, Valid loss: 0.4329, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1136, Valid loss: 0.4320, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1136, Valid loss: 0.4341, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1141, Valid loss: 0.4430, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1096, Valid loss: 0.4442, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1141, Valid loss: 0.4425, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.1107, Valid loss: 0.4540, Learn rate: 0.0010
#
# Round completed

# %% [markdown]
# # VALIDATION

# %%
def descale(value, MEAN, SD):
    return value * SD + MEAN

device = torch.device("cuda:1")
model_path = 'model/lsbmd/ResNet34/ResNet34'
model_test = Network()
model_test.load_state_dict(torch.load("../model/lsbmd/ResNet34/ResNet34_e61-90.pt"))
model_test.to("cuda:1")
description = "e61-90"

test_df =  df[df['purpose'].isin(["VALID"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true = []
Y_pred = []

with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        print(image_address)
        image, value = image.to(device), value.to(device)
        output = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))  

results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
results_new.reset_index(drop=True).to_csv(home_path + model_path + '_VALIDRESULTS.csv', index =False)
print("Round completed")
# Out:
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3886_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/779_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/4108_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2037_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1622_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/894_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/434_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/4070_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1577_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1684_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3120_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3088_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1765_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/4119_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/437_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2742_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/121_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/45_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2329_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2181_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3478_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/875_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1562_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3379_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/534_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1139_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2955_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2132_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3672_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1305_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3124_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1203_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/348_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1683_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1235_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1858_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/4130_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra
1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/4131_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3247_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2721_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2093_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1314_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/4131_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1935_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1231_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2032_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1684_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1531_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2746_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1171_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/641_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3660_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/495_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2004_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2341_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/442_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1510_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1629_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3877_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1819_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1719_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1837_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2738_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3296_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/465_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3505_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2829_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1320_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/266_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1064_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2332_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/441_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3275_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1419_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/688_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1284_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2084_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3766_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3859_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2665_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1456_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2023_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/931_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/662_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3122_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/184_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/418_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2599_1_L3.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1676_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/4047_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3978_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2368_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/908_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1203_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/3959_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1090_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1084_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1162_1_L4.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/297_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/1281_1_L2.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/495_1_L1.jpg
# /projects/ghnguyen_proj/project/git/ebmd/data/vertebra/2023_1_L3.jpg
# Round completed

# %%
home_path = "/projects/ghnguyen_proj/project/git/ebmd/"
dataset_address = home_path + "data/vertebra/"
df = pd.read_csv(home_path + "instruction/lsbmd_phase1_instruction.csv")
df["image"] = dataset_address + df["FNAME"]
df["bmd_scaled"] = (df["BMD"] - df["mBMD"]) / df["sdBMD"]
df["purpose"] = df["PURPOSE"]
df['exist'] = df['image'].map(os.path.exists)
df['bmd_category'] = pd.cut(df['bmd_scaled'], 50, labels=range(50)).astype("int")
df[['bmd_scaled']].hist(figsize = (10, 4))

device = torch.device("cuda:1")
model_path = 'model/lsbmd/ResNet34/ResNet34_ENSEMBLE'
model_test = Network()
model_test.load_state_dict(torch.load("../model/lsbmd/ResNet34/ResNet34_e61-90.pt"))
model_test.to(device)

test_df =  df[df['purpose'].isin(["TEST"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true, Y_pred = [], []
with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        image, value = image.to(device), value.to(device)
        output_ = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output_.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))

results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred})
results_new["X"] = results_new["X"].apply(os.path.basename)
results_new.reset_index(drop=True).to_csv(home_path + model_path + '_TEST.csv', index =False)

test_df =  df[df['purpose'].isin(["VALID"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true, Y_pred = [], []
with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        image, value = image.to(device), value.to(device)
        output_ = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output_.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))

results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred})
results_new["X"] = results_new["X"].apply(os.path.basename)
results_new.reset_index(drop=True).to_csv(home_path + model_path + '_TRAIN.csv', index =False)
print("Round completed")
# Out:
# Round completed
