# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm
from PIL import Image
import torch
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import datasets, models, transforms
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import lightning as L
from lightning.pytorch.callbacks.early_stopping import EarlyStopping
# Out:
# /tmp/ipykernel_165372/3725667653.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
def img_display(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    npimg = np.transpose(npimg, (1, 2, 0))
    return npimg

class XBMD_Dataset(Dataset):
    def __init__(self, img_data, img_path,transform=None):
        self.img_path = img_path
        self.transform = transform
        self.img_data = img_data

    def __len__(self):
        return len(self.img_data)
    
    def __getitem__(self, index):
        image_address = os.path.join(self.img_path, self.img_data.loc[index, 'image'])
        image = Image.open(image_address).convert("RGB")
        image = image.resize((384,384))
        value = torch.tensor(self.img_data.loc[index, 'bmd_scaled'])
        if self.transform is not None:
            image = self.transform(image)
        return image_address, image.float(), value.float()
    
class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.backbone = models.vgg16(weights = "IMAGENET1K_V1")
        self.regressor = nn.Sequential(nn.Linear(1000, 500)
                                      ,nn.Linear(500, 1))

    def forward(self, x):
        x=self.backbone(x)
        x=self.regressor(x)
        return x
    
def descale(value, MEAN, SD):
    return value * SD + MEAN

# %%
home_path = "/projects/ghnguyen_proj/project/git/ebmd/"
dataset_address = home_path + "data/vertebra/"
df = pd.read_csv(home_path + "instruction/lsbmd_phase1_instruction.csv")
df["image"] = dataset_address + df["FNAME"]
df["bmd_scaled"] = (df["BMD"] - df["mBMD"]) / df["sdBMD"] 
df["purpose"] = df["PURPOSE"]
df['exist'] = df['image'].map(os.path.exists)
df['bmd_category'] = pd.cut(df['bmd_scaled'], 50, labels=range(50)).astype("int")
df[['bmd_scaled']].hist(figsize = (10, 4))
print('images found of', df.shape[0], 'total')
raw_train_df = df[df['purpose'].isin(["TRAIN"])]
valid_df =  df[df['purpose'].isin(["VALID"])]
print('Train amount: ', raw_train_df.shape[0], 'Validation amount: ', valid_df.shape[0])
train_df = raw_train_df.groupby(['bmd_category']).apply(lambda x: x.sample(max(raw_train_df["bmd_category"].value_counts()), replace = True)).reset_index(drop = True)
train_df[['bmd_scaled']].hist(figsize = (10, 4), bins=50)
print('New Data Size:', train_df.shape[0], 'Old Size:', raw_train_df.shape[0])
# Out:
# images found of 13498 total
# Train amount:  7554 Validation amount:  1976
# New Data Size: 15350 Old Size: 7554

# %%
BATCH_SIZE = 32

train_indices = list(train_df.index)
train_sampler = SubsetRandomSampler(train_indices)
train_transform = transforms.Compose(
    [transforms.ToTensor()
    ,transforms.RandomAffine(degrees=(0, 5), translate=(0, 0.1), scale=(0.8, 1.2))
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
train_dataset = XBMD_Dataset(train_df, dataset_address, train_transform)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=train_sampler)

valid_indices = list(valid_df.index)
valid_sampler = SubsetRandomSampler(valid_indices)
valid_transform = transforms.Compose(
    [transforms.ToTensor()                                
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
valid_dataset = XBMD_Dataset(valid_df, dataset_address, valid_transform)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, sampler=valid_sampler)

# %%
dataiter = iter(train_loader)
_, images, values = next(dataiter)
fig, axis = plt.subplots(5, 5, figsize=(18, 18))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, value = images[i], values[i]
        ax.imshow(img_display(image)@ [0.299, 0.587, 0.113], cmap = "gray")
        ax.set(title = f"{round(value.item(),3)}")

# %%
device = torch.device("cuda:0")
model = Network()
#model.load_state_dict(torch.load("../model/VGG16.pt"))
model.to(device)
print("Model initialised")
# Out:
# Model initialised

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %%
model_path = 'model/lsbmd/VGG16/VGG16'

# %%
def descale(value, MEAN, SD):
    return value * SD + MEAN

n_epochs = 30
print_every = 1
description = "e61-90"

try:
    old_file_existed = True
    record_current = pd.read_csv(home_path + model_path + ".csv")
    record_new = []
    train_loss = record_current["train_loss"].to_list()
    val_loss = record_current["val_loss"].to_list()
    valid_loss_min = np.min(val_loss)
    learning_rate = record_current["lr"].values[-1]
    print("Old file existed.")
except:
    old_file_existed = False
    record_current = []
    record_new = []
    train_loss = []
    val_loss = []
    valid_loss_min = np.inf
    learning_rate = 0.001
    print("Old file not existed, create new file...")

print("learning rate: ", learning_rate)

total_step = len(train_loader)

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)
scheduler = ReduceLROnPlateau(optimizer, 'min', patience = 5)

for epoch in range(1, n_epochs+1):
    model.train()
    running_loss = 0.0
    correct = 0
    total=0
    with tqdm(train_loader, unit="batch") as tepoch:
        tepoch.set_description(f'Epoch [{epoch}/{n_epochs}]') #print epoch
        for batch_idx, (_, data_, target_) in enumerate(tepoch):
            data_, target_ = data_.to(device), target_.to(device)# on GPU
            optimizer.zero_grad()
            outputs = model(data_)
            loss = criterion(outputs, target_.unsqueeze(1))
            loss.backward()
            optimizer.step()
            running_loss += loss.item()    
        batch_loss = 0
        total_t=0
        correct_t=0
        with torch.no_grad():
            model.eval()
            for _, data_t, target_t in (valid_loader):
                data_t, target_t = data_t.to(device), target_t.to(device)
                outputs_t = model(data_t)
                loss_t = criterion(outputs_t, target_t.unsqueeze(1))
                batch_loss += loss_t.item()
            val_loss = np.append(val_loss, batch_loss/len(valid_loader))
            network_learned = batch_loss/len(valid_loader) < valid_loss_min
            if network_learned: 
                valid_loss_min = batch_loss/len(valid_loader)
                torch.save(model.state_dict(), home_path + model_path + "_" + description + '.pt')
                print('Detected network improvement, saving current model')
        scheduler.step(np.mean(val_loss))
        record_new.append([running_loss/total_step, batch_loss/len(valid_loader), optimizer.param_groups[0]['lr'], description])
    print('Train loss: {:.4f}, Valid loss: {:.4f}, Learn rate: {:.4f}\n' 
       .format(running_loss/total_step, batch_loss/len(valid_loader), optimizer.param_groups[0]['lr']))

model_test = Network()
model_test.load_state_dict(torch.load(home_path + model_path + "_" + description + '.pt'))
model_test.to("cpu")

test_df =  df[df['purpose'].isin(["TEST"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true = []
Y_pred = []
with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        output_ = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output_.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))

if old_file_existed == True:
    record_new = pd.DataFrame(record_new, columns = ["train_loss","val_loss","lr","note"])
    record_new["epoch"] = range((np.max(record_current["epoch"])+1),(np.max(record_current["epoch"])+1+n_epochs),1)
    pd.concat([record_current, record_new], axis=0).reset_index(drop=True).to_csv(home_path + model_path + '.csv', index = False)   
    results_current = pd.read_csv(home_path + model_path + "_TESTRESULTS.csv")
    results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
    pd.concat([results_current, results_new], axis=0).reset_index(drop=True).to_csv(home_path + model_path + '_TESTRESULTS.csv', index = False)
else:
    record_new = pd.DataFrame(record_new, columns = ["train_loss","val_loss","lr","note"])
    record_new["epoch"] = range(1,n_epochs+1,1)
    record_new.reset_index(drop=True).to_csv(home_path + model_path + '.csv', index =False)   
    results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
    results_new.reset_index(drop=True).to_csv(home_path + model_path + '_TESTRESULTS.csv', index =False)
print("Round completed")
# Out:
# Old file existed.
# learning rate:  0.001
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0826, Valid loss: 0.4443, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0827, Valid loss: 0.4880, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.0809, Valid loss: 0.4202, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0801, Valid loss: 0.4235, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0782, Valid loss: 0.4357, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0748, Valid loss: 0.4273, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Detected network improvement, saving current model
# Train loss: 0.0761, Valid loss: 0.4182, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0744, Valid loss: 0.4232, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0729, Valid loss: 0.4267, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0736, Valid loss: 0.4238, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0717, Valid loss: 0.4248, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0723, Valid loss: 0.4297, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0702, Valid loss: 0.4197, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0682, Valid loss: 0.4369, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0684, Valid loss: 0.4367, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0656, Valid loss: 0.4256, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0657, Valid loss: 0.4225, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0645, Valid loss: 0.4609, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0663, Valid loss: 0.4207, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0639, Valid loss: 0.4244, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0634, Valid loss: 0.4283, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0622, Valid loss: 0.4228, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0629, Valid loss: 0.4248, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0622, Valid loss: 0.4394, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0611, Valid loss: 0.4187, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0603, Valid loss: 0.4269, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0592, Valid loss: 0.4190, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0580, Valid loss: 0.4253, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0595, Valid loss: 0.4257, Learn rate: 0.0010
#   0%|          | 0/480 [00:00<?, ?batch/s]
# Train loss: 0.0574, Valid loss: 0.4258, Learn rate: 0.0010
#
# Round completed

# %%
home_path = "/projects/ghnguyen_proj/project/git/ebmd/"
dataset_address = home_path + "data/hip/total/"
df = pd.read_csv(home_path + "instruction/fnbmd_phase1_instruction.csv")
df["image"] = dataset_address + df["FNAME"]
df["bmd_scaled"] = (df["BMD"] - df["mBMD"]) / df["sdBMD"] 
df["purpose"] = df["PURPOSE"]
df['exist'] = df['image'].map(os.path.exists)
df['bmd_category'] = pd.cut(df['bmd_scaled'], 50, labels=range(50)).astype("int")
df[['bmd_scaled']].hist(figsize = (10, 4))

device = torch.device("cuda:1")
model_path = 'model/fnbmd/VGG16/VGG16_ENSEMBLE'
model_test = Network()
model_test.load_state_dict(torch.load("../model/fnbmd/VGG16/VGG16_e01-10.pt"))
model_test.to(device)
description = "Ensemble"

test_df =  df[df['purpose'].isin(["TEST"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true = []
Y_pred = []

with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        print(image_address)
        image, value = image.to(device), value.to(device)
        output = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))  

results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred, "note": description})
results_new.reset_index(drop=True).to_csv(home_path + model_path + '_TESTRESULTS.csv', index =False)
print("Round completed")
# Out:
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/897.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2077.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2326.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/279.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4093.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3378.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3793.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/474.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2167.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2195.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/332.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1146.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3962.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3526.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4097.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4064.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2634.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2102.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2026.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2062.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3106.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3429.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1051.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2507.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/460.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2996.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2742.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1349.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1397.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/855.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2902.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1488.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2334.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1651.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3341.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2010.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2906.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1873.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3912.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1275.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3105.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4045.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/347.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1162.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2349.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3791.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/703.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/351.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2977.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3682.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1634.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2477.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2494.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/283.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3392.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2609.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1776.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3864.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1803.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2097.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2929.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3302.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3402.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1554.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2154.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1302.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3976.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3090.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1314.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1681.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/413.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3711.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2506.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2455.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3755.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1751.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1683.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3692.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/825.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/321.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4044.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/778.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3991.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1479.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3032.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1067.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2382.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3544.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1862.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2392.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1393.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3926.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3985.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1997.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/976.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/89.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1732.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3361.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/148.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2305.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/315.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2884.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2656.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/197.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3898.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2639.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2570.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1660.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2668.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/107.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/244.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/453.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/422.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3102.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4127.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3010.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3780.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4165.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1139.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/45.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/789.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1255.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3226.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4074.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/389.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2613.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1765.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2033.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2252.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1956.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2883.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1558.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2030.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1270.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1148.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/532.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1684.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1865.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2360.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4106.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2985.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2270.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2183.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/52.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4114.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2364.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1510.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4040.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/763.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3097.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1922.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2837.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1502.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2125.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4050.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/787.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3333.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2454.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1311.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1985.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3348.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/729.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2124.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1170.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2430.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1852.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3515.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1725.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3015.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/458.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3383.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2969.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3676.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2629.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3623.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1974.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3494.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/501.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1337.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1283.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2921.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2138.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4202.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/
png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3123.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2622.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4201.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2122.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3019.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/690.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1369.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/215.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/915.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1993.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/4148.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2283.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2022.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1695.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1120.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/949.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2405.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2478.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/3743.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/1697.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2601.png
# /projects/ghnguyen_proj/project/git/ebmd/data/hip/total/2366.png
# Round completed

# %%
home_path = "/projects/ghnguyen_proj/project/git/ebmd/"
dataset_address = home_path + "data/vertebra/"
df = pd.read_csv(home_path + "instruction/lsbmd_phase1_instruction.csv")
df["image"] = dataset_address + df["FNAME"]
df["bmd_scaled"] = (df["BMD"] - df["mBMD"]) / df["sdBMD"]
df["purpose"] = df["PURPOSE"]
df['exist'] = df['image'].map(os.path.exists)
df['bmd_category'] = pd.cut(df['bmd_scaled'], 50, labels=range(50)).astype("int")
df[['bmd_scaled']].hist(figsize = (10, 4))

device = torch.device("cuda:1")
model_path = 'model/lsbmd/VGG16/VGG16_ENSEMBLE'
model_test = Network()
model_test.load_state_dict(torch.load("../model/lsbmd/VGG16/VGG16_e61-90.pt"))
model_test.to(device)

test_df =  df[df['purpose'].isin(["TEST"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true, Y_pred = [], []
with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        image, value = image.to(device), value.to(device)
        output_ = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output_.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))

results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred})
results_new["X"] = results_new["X"].apply(os.path.basename)
results_new.reset_index(drop=True).to_csv(home_path + model_path + '_TEST.csv', index =False)

test_df =  df[df['purpose'].isin(["VALID"])]
test_indices = list(test_df.index)
test_sampler = SubsetRandomSampler(test_indices)
test_transform = transforms.Compose(
    [transforms.ToTensor()                             
    ,transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
test_dataset = XBMD_Dataset(test_df, dataset_address, test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=len(test_indices), sampler=test_sampler)
dataiter = iter(test_loader)
images_address, images, values = next(dataiter)    
Y_true, Y_pred = [], []
with torch.no_grad():     
    model_test.eval()
    for image_address, image, value in (zip(images_address, images, values)):
        image, value = image.to(device), value.to(device)
        output_ = model_test(image.unsqueeze_(0))
        Y_pred.append(descale(output_.item(), df["mBMD"][0], df["sdBMD"][0]))
        Y_true.append(descale(value.item(), df["mBMD"][0], df["sdBMD"][0]))

results_new = pd.DataFrame({"X": images_address,"Y_true": Y_true, "Y_pred": Y_pred})
results_new["X"] = results_new["X"].apply(os.path.basename)
results_new.reset_index(drop=True).to_csv(home_path + model_path + '_TRAIN.csv', index =False)
print("Round completed")
# Out:
# Round completed
